# %%
import pandas as pd
df=pd.read_parquet("../data/processed/02_cleaned.parquet")

# %%
df.shape
# Out:
# (99, 5)

# %%
df.head()
# Out:
#             timestamp  temperature  humidity     CO2  yield
# 0 2026-06-01 00:00:00         25.7      92.3   827.0   2.81
# 1 2026-06-01 01:00:00         27.8      94.8  1083.0   4.10
# 2 2026-06-01 02:00:00         27.0      83.3   744.0   1.45
# 3 2026-06-01 03:00:00         24.8      80.9   764.0   3.78
# 4 2026-06-01 04:00:00         24.2      84.7  1158.0   2.74

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   timestamp    99 non-null     datetime64[us]
#  1   temperature  99 non-null     float64
#  2   humidity     99 non-null     float64
#  3   CO2          99 non-null     float64
#  4   yield        99 non-null     float64
# dtypes: datetime64[us](1), float64(4)
# memory usage: 4.0 KB

# %%
df.describe()
# Out:
#                         timestamp  temperature   humidity          CO2  \
# count                          99    99.000000  99.000000    99.000000
# mean   2026-06-03 01:23:38.181818    25.197868  87.901010   892.222222
# min           2026-06-01 00:00:00    22.300000  80.100000   600.000000
# 25%           2026-06-02 00:30:00    23.700000  83.850000   728.500000
# 50%           2026-06-03 01:00:00    25.188889  88.000000   866.000000
# 75%           2026-06-04 02:30:00    26.500000  92.300000  1082.000000
# max           2026-06-05 03:00:00    27.900000  94.900000  1198.000000
# std                           NaN     1.685108   4.791457   184.293275
#
#            yield
# count  99.000000
# mean    2.644343
# min     0.520000
# 25%     1.425000
# 50%     2.670000
# 75%     3.910000
# max     4.940000
# std     1.349115

# %%
numeric_df = df[["temperature", "humidity", "CO2", "yield"]]
corr = numeric_df.corr()
corr
# Out:
#              temperature  humidity       CO2     yield
# temperature     1.000000  0.128276  0.117508  0.092683
# humidity        0.128276  1.000000 -0.078093  0.042102
# CO2             0.117508 -0.078093  1.000000  0.141309
# yield           0.092683  0.042102  0.141309  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))
sns.heatmap(
    corr,
    annot=True,
    cmap="coolwarm"
)
plt.title("Correlation Heatmap")
plt.savefig("../reports/figures/correlation_heatmap.png")
plt.show()

# %%
plt.scatter(df["temperature"], df["yield"])
plt.xlabel("Temperature (°C)")
plt.ylabel("Yield (kg)")
plt.title("Temperature vs Yield")
plt.savefig("../reports/figures/temperature_vs_yield.png")
plt.show()

# %%
plt.scatter(df["CO2"], df["yield"])
plt.xlabel("CO2 (ppm)")
plt.ylabel("Yield (kg)")
plt.title("CO2 vs Yield")
plt.savefig("../reports/figures/co2_vs_yield.png")
plt.show()

# %%
plt.scatter(df["humidity"], df["yield"])
plt.xlabel("Humidity (%)")
plt.ylabel("Yield (kg)")
plt.title("Humidity vs Yield")
plt.savefig("../reports/figures/humidity_vs_yield.png")
plt.show()
