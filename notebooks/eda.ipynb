# %%
import pandas as pd
df=pd.read_parquet("../data/processed/02_cleaned.parquet")

# %%
df.shape
# Out:
# (99, 5)

# %%
df.head()
# Out:
#             timestamp  temperature  humidity     CO2  yield
# 0 2026-06-01 00:00:00         23.0      90.1   654.0   3.96
# 1 2026-06-01 01:00:00         24.4      88.4   669.0   2.29
# 2 2026-06-01 02:00:00         22.8      86.3  1125.0   2.53
# 3 2026-06-01 03:00:00         22.8      81.3   807.0   3.61
# 4 2026-06-01 04:00:00         25.4      94.8  1179.0   2.22

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   timestamp    99 non-null     datetime64[ns]
#  1   temperature  99 non-null     float64
#  2   humidity     99 non-null     float64
#  3   CO2          99 non-null     float64
#  4   yield        99 non-null     float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 4.0 KB

# %%
df.describe()
# Out:
#                            timestamp  temperature   humidity          CO2  \
# count                             99    99.000000  99.000000    99.000000
# mean   2026-06-03 01:23:38.181818112    24.804061  87.391919   909.333333
# min              2026-06-01 00:00:00    22.000000  80.200000   611.000000
# 25%              2026-06-02 00:30:00    22.950000  83.600000   765.500000
# 50%              2026-06-03 01:00:00    24.700000  87.600000   899.000000
# 75%              2026-06-04 02:30:00    26.500000  91.000000  1079.500000
# max              2026-06-05 03:00:00    27.900000  94.800000  1197.000000
# std                              NaN     1.846559   4.287159   178.051758
#
#            yield
# count  99.000000
# mean    2.653333
# min     0.640000
# 25%     1.430000
# 50%     2.660000
# 75%     3.795000
# max     4.920000
# std     1.317996

# %%
numeric_df = df[["temperature", "humidity", "CO2", "yield"]]
corr = numeric_df.corr()
corr
# Out:
#              temperature  humidity       CO2     yield
# temperature     1.000000 -0.052755 -0.067945  0.056216
# humidity       -0.052755  1.000000  0.028990 -0.072866
# CO2            -0.067945  0.028990  1.000000 -0.043371
# yield           0.056216 -0.072866 -0.043371  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))
sns.heatmap(
    corr,
    annot=True,
    cmap="coolwarm"
)
plt.title("Correlation Heatmap")
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.scatter(df["temperature"], df["yield"])
plt.xlabel("Temperature (°C)")
plt.ylabel("Yield (kg)")
plt.title("Temperature vs Yield")
plt.savefig("../reports/figures/temperature_vs_yield.png")
plt.show()

# %%
plt.scatter(df["CO2"], df["yield"])
plt.xlabel("CO2 (ppm)")
plt.ylabel("Yield (kg)")
plt.title("CO2 vs Yield")
plt.savefig("../reports/figures/co2_vs_yield.png")
plt.show()

# %%
plt.scatter(df["humidity"], df["yield"])
plt.xlabel("Humidity (%)")
plt.ylabel("Yield (kg)")
plt.title("Humidity vs Yield")
plt.savefig("../reports/figures/humidity_vs_yield.png")
plt.show()
